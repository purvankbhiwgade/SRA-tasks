# %%
import numpy as np
import cv2
from google.colab.patches import cv2_imshow
from PIL import Image

# %%
img = np.array(Image.open('/content/drive/My Drive/Colab Notebooks/edge_detection/edge-detection2.jpg'))


# result = np.zeros((img.shape[0]+4,img.shape[1]+4,img.shape[2]))
result = np.zeros((img.shape[0]+2,img.shape[1]+2,img.shape[2]))

# print(result.shape)
# # print(result)
# result[2 :-2,2:-2,:] = img
result[1 :-1,1:-1,:] = img
# cv2_imshow(result)
# print(result.dtype)

# print(result[4][4]*2)
# # [189. 145.  84.]

# %%
vertical_sober = np.array([
                           [-1,-2,-1],
                           [0,0,0],
                           [1,2,1]
                          ])

horizontal_sober = [[-1,0,1], 
                     [-2,0,2], 
                     [-1,0,1]]

# %%
sharped = np.zeros(img.shape)

def multiplier(kernel):
  for i in range(img.shape[0]):
    for j in range(img.shape[1]):
      imp = result[i: i+3, j: j+3, 0]
      
      transformed_pixels = kernel*imp

      transform_score = transformed_pixels.sum()/4

      sharped[i,j] = [transform_score]*3
      

multiplier(vertical_sober)
cv2_imshow(sharped)
print('HI')
multiplier(horizontal_sober)
cv2_imshow(sharped)
# Out:
# <PIL.Image.Image image mode=RGB size=340x340 at 0x7FA0D2A55828>
# HI
# <PIL.Image.Image image mode=RGB size=340x340 at 0x7FA0D2A557F0>
